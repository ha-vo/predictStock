# %%
from yahoo_fin.stock_info import get_data
from datetime import datetime
today = datetime.now().strftime("%d/%m/%Y")
data = get_data("MSFT", start_date="01/01/2015", end_date=today, index_as_date = True, interval="1d")
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\yahoo_fin\stock_info.py:29: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   end_seconds = int(pd.Timestamp(end_date).timestamp())

# %%
for i in amazon_weekly.index:
    print(type(i.strftime("%d/%m/%Y")))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
series_shift = data['close'].shift()
data['pre_close'] = series_shift
data['pre_open'] = data['open'].shift()

# %%
amazon_weekly
# Out:
#                   open        high         low       close    adjclose  \
# 2009-12-04    7.171000    7.172500    6.755500    6.879000    6.879000
# 2009-12-07    6.900000    6.950000    6.692000    6.710500    6.710500
# 2009-12-08    6.715000    6.804000    6.643500    6.705500    6.705500
# 2009-12-09    6.730000    6.735500    6.491000    6.565500    6.565500
# 2009-12-10    6.620500    6.809500    6.620000    6.769000    6.769000
# ...                ...         ...         ...         ...         ...
# 2024-03-08  176.440002  178.789993  174.330002  175.350006  175.350006
# 2024-03-11  174.309998  174.470001  171.470001  171.960007  171.960007
# 2024-03-12  173.500000  176.759995  171.979996  175.389999  175.389999
# 2024-03-13  175.899994  177.619995  175.550003  176.559998  176.559998
# 2024-03-14  177.690002  179.529999  176.470001  178.750000  178.750000
#
#                volume ticker   pre_close    pre_open
# 2009-12-04  296548000   AMZN         NaN         NaN
# ...

# %%
data.dropna(inplace=True)
data
# Out:
#                   open        high         low       close    adjclose  \
# 2015-01-05   46.369999   46.730000   46.250000   46.330002   40.006760
# 2015-01-06   46.380001   46.750000   45.540001   45.650002   39.419567
# 2015-01-07   45.980000   46.459999   45.490002   46.230000   39.920406
# 2015-01-08   46.750000   47.750000   46.720001   47.590000   41.094784
# 2015-01-09   47.610001   47.820000   46.900002   47.189999   40.749382
# ...                ...         ...         ...         ...         ...
# 2024-03-11  403.760010  405.679993  401.260010  404.519989  404.519989
# 2024-03-12  407.619995  415.570007  406.790009  415.279999  415.279999
# 2024-03-13  418.100006  418.179993  411.450012  415.100006  415.100006
# 2024-03-14  420.239990  427.820007  417.989990  425.220001  425.220001
# 2024-03-15  419.290009  422.600006  412.790009  416.420013  416.420013
#
#               volume ticker   pre_close    pre_open
# 2015-01-05  39673900   MSFT   46.759998   46.660000
# ...

# %%
X_predictClose = data[["pre_close","open"]].values
y_predictClose = data['close'].values
X_predictOpen = data[["pre_close","pre_open"]].values
y_predictOpen = data['open'].values

# %%
import numpy as np
x = np.asarray([y_predictClose[-1], y_predictOpen[-1]])

# %%
print(X_predictOpen)
print(x)
# Out:
# [[ 46.75999832  46.65999985]
#  [ 46.33000183  46.36999893]
#  [ 45.65000153  46.38000107]
#  ...
#  [415.27999878 407.61999512]
#  [415.1000061  418.1000061 ]
#  [425.22000122 420.23999023]]
# [416.42001343 419.29000854]

# %%
X_predictOpen = np.vstack((X_predictOpen,x))
X_predictOpen
# Out:
# array([[ 46.75999832,  46.65999985],
#        [ 46.33000183,  46.36999893],
#        [ 45.65000153,  46.38000107],
#        ...,
#        [415.1000061 , 418.1000061 ],
#        [425.22000122, 420.23999023],
#        [416.42001343, 419.29000854]])

# %%
print(y_predictOpen)
# Out:
# [ 46.36999893  46.38000107  45.97999954 ... 418.1000061  420.23999023
#  419.29000854]

# %%
y_predictOpen = np.append(y_predictOpen, 123)
y_predictOpen
# Out:
# array([ 46.36999893,  46.38000107,  45.97999954, ..., 420.23999023,
#        419.29000854, 123.        ])

# %% [markdown]
# # predict open price

# %%
X = amazon_weekly[["pre_close","pre_open"]].values
y = amazon_weekly["open"].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 32, test_size = 1/4)

# %%
ln = LinearRegression().fit(X_train, y_train)

# %%
y_pred = ln.predict(X_test)

# %%
for i in range(20):
    print(y_test[i], y_pred[i])
# Out:
# 19.3700008392334 19.345837631865425
# 17.966999053955078 17.913325053306817
# 10.369999885559082 10.443723326962164
# 29.835500717163086 29.760708730705836
# 17.649999618530273 17.637400392232703
# 160.14999389648438 161.21090965525934
# 168.1614990234375 167.141057746773
# 122.75050354003906 122.35410351930618
# 26.872499465942383 26.84618414304291
# 12.654999732971191 12.696590365380464
# 89.98100280761719 89.7165706946495
# 11.31149959564209 11.274298117895189
# 178.36599731445312 177.64636813774118
# 129.5 127.98702281928102
# 41.63800048828125 41.80524078626607
# 11.696499824523926 11.751425834826406
# 6.397500038146973 6.472668453880283
# 160.5 159.59893544384994
# 33.39699935913086 33.10487785597205
# 17.10449981689453 17.13670878715466

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print('Coefficient of determination (R^2): %.2f' % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 1.13
# Coefficient of determination (R^2): 1.00

# %% [markdown]
# ## predict the close price

# %%
X = amazon_weekly[["pre_close","open"]].values
y = amazon_weekly["close"].values
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 32, test_size = 1/4)
ln = LinearRegression().fit(X_train, y_train)
y_pred = ln.predict(X_test)

for i in range(20):
    print(y_test[i], y_pred[i])
# Out:
# 19.721500396728516 19.392507598501936
# 17.86750030517578 17.989719104357338
# 10.728500366210938 10.40417788512555
# 29.934499740600586 29.84507461657692
# 17.916000366210938 17.67416516692554
# 162.13800048828125 160.05400204080985
# 163.635498046875 168.0015141032193
# 121.84400177001953 122.65732831654404
# 26.75149917602539 26.8870226759779
# 12.388500213623047 12.686023297484743
# 89.32499694824219 89.92287322365144
# 11.565999984741211 11.34189747347188
# 178.6595001220703 178.20377111166147
# 127.51000213623047 129.36907380002526
# 41.12950134277344 41.64175976494476
# 11.70300006866455 11.728855507638038
# 6.5 6.435862398051878
# 164.33250427246094 160.35417547125985
# 33.42250061035156 33.39824743261214
# 17.159000396728516 17.130395915205078

# %%
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print('Coefficient of determination (R^2): %.2f' % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 1.81
# Coefficient of determination (R^2): 1.00
